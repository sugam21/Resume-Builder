# %%
# The directory for top level folder
dir_ = "/home/sugam/Work/10-19 NLP/12 Projects/Resume Builder/data/"

# %%
raw_data_dir = dir_ + 'raw/'
processed_data_dir = dir_+'Processed/'

# %% [markdown]
# # 1. Part-1

# %%
import pandas as pd
import numpy as np

# %%
####################### LOAD DATA
##################################################################
def load_data(url: str) ->pd.DataFrame:
    """
    Loads the dataframe into memory

    Args:
      url (string) - the path to the dataframe

    Returns:
      df (pandas dataframe)
    """
    
    print("⏳ Loading Data")
    
    # Refering our data without any modification and dtype
    if(url[-3:]=="csv"):
        df = pd.read_csv(url)
        
        for col in list(df):  # List out the column names
            if "Unnamed" in col:  # Checks if the column contains Unnamed in it 
                df.drop(col, axis=1,inplace=True) # Removes the Garbage column
    else:
        df = pd.read_json(url, lines=True)


    
    print(f"✅ Done Loading")    
    return df


ds_dir= raw_data_dir+"data_scientist_united_states_job_postings_jobspikr.csv"
software_developers_dir = raw_data_dir+"software_developer_united_states_1971_20191023_1(1).csv"
marketing_dir = raw_data_dir+"marketing_sample_for_seek_au-jobs_listing__20190901_20191231__10k_data.json"

ds = load_data(ds_dir)
software_developers = load_data(software_developers_dir)
marketing = load_data(marketing_dir)
# Out:
# ⏳ Loading Data
# ✅ Done Loading
# ⏳ Loading Data
# ✅ Done Loading
# ⏳ Loading Data
# ✅ Done Loading

# %%
# Dropping unnecessary columns from the dataframes
ds.drop(["crawl_timestamp","html_job_description","uniq_id","contact_phone_number","cursor"], axis=1,inplace=True)
software_developers.drop(["crawl_timestamp","uniq_id","contact_phone_number","cursor"], axis=1,inplace=True)
marketing.drop(["uniq_id","crawl_timestamp","html_job_description"], axis=1,inplace=True)

# %%
# Joining everything into a single dataframe and deleting the rest.
marketing = marketing[ds.columns]

main_df = pd.concat([ds,software_developers,marketing])
main_df.drop(["salary_offered","geo","job_board","city","state","inferred_city","inferred_state","inferred_country","contact_email"],axis=1,inplace=True)
del ds, software_developers, marketing

# %%
main_df.head()
# Out:
#                                                  url  \
# 0  https://www.indeed.com/viewjob?jk=fd83355c2b23...
# 1  https://www.dice.com/jobs/detail/Data-Scientis...
# 2  https://www.dice.com/jobs/detail/Data-Scientis...
# 3  https://www.indeed.com/viewjob?jk=841edd86ead2...
# 4  https://job-openings.monster.com/senior-data-s...
#
#                                            job_title            category  \
# 0                        Enterprise Data Scientist I  Accounting/Finance
# 1                                     Data Scientist                 NaN
# 2                                     Data Scientist                 NaN
# 3  Data Scientist, Aladdin Wealth Tech, Associate...  Accounting/Finance
# 4                              Senior Data Scientist             biotech
#
#                            company_name country   post_date  \
# 0               Farmers Insurance Group     Usa  2019-02-06
# 1                        Luxoft USA Inc     Usa  2019-02-05
# 2  Cincinnati Bell Technology Solutions     Usa  2019-02-05
# 3                             BlackRock     Usa  2019-02-06
# 4                           CyberCoders     Usa  2019-02-05
#
#                                      job_description   job_type
# 0  Read what people are saying about working here...  Undefined
# 1  We have an immediate opening for a Sharp Data ...  Undefined
# 2  Candidates should have the following backgroun...  Full Time
# 3  Read what people are saying about working here...  Undefined
# 4  We are seeking an extraordinary Data Scientist...  Full Time

# %%
main_df.shape
# Out:
# (30000, 8)

# %%
main_df.isnull().sum()
# Out:
# url                   0
# job_title             0
# category           1721
# company_name          0
# country               0
# post_date             0
# job_description       0
# job_type              0
# dtype: int64

# %%
main_df["country"] = main_df["country"].fillna("Unknown")
main_df["company_name"] = main_df["company_name"].fillna("Unknown")

# %%
main_df[main_df["category"].isnull()]
# Out:
#                                                     url  \
# 1     https://www.dice.com/jobs/detail/Data-Scientis...
# 2     https://www.dice.com/jobs/detail/Data-Scientis...
# 7     https://www.dice.com/jobs/detail/Sr.-Data-Scie...
# 9     https://www.dice.com/jobs/detail/Data-Scientis...
# 11    https://www.dice.com/jobs/detail/Data-Scientis...
# ...                                                 ...
# 9612  https://www.dice.com/jobs/detail/Software-Deve...
# 9756  https://www.dice.com/jobs/detail/Software-Deve...
# 9886  https://www.dice.com/jobs/detail/Senior-Java-%...
# 9985  https://www.dice.com/jobs/detail/Senior-Full-S...
# 9986  https://www.dice.com/jobs/detail/Full-Stack-So...
#
#                                         job_title category  \
# 1                                  Data Scientist      NaN
# 2                                  Data Scientist      NaN
# 7     Sr. Data Scientist (Can work on Xoriant W2)      NaN
# 9                                  Data Scientist      NaN
# 11                                 Data Scientist      NaN
# ...                                           ...      ...
# 9612                   Software Developer (Kafka)      NaN
# 9756              Software Developer & Integrator      NaN
# 9886        Senior Java / J2EE Software Developer      NaN
# 9985         Senior Full Stack Software Developer      NaN
# 9986              Full Stack Software Developer 3      NaN
#
#                               company_name country   post_date  \
# 1                           Luxoft USA Inc     Usa  2019-02-05
# 2     Cincinnati Bell Technology Solutions     Usa  2019-02-05
# 7                      Xoriant Corporation     Usa  2019-02-06
# 9                         Adroit Resources     Usa  2019-02-05
# 11             Envoy Consulting Group, Inc     Usa  2019-02-05
# ...                                    ...     ...         ...
# 9612                     Goahead Solutions      US  2019-07-29
# 9756            Kforce Technology Staffing      US  2019-07-31
# 9886            Kforce Technology Staffing      US  2019-08-01
# 9985            Kforce Technology Staffing      US  2019-08-02
# 9986            Kforce Technology Staffing      US  2019-08-02
#
#                                         job_description   job_type
# 1     We have an immediate opening for a Sharp Data ...  Undefined
# 2     Candidates should have the following backgroun...  Full Time
# 7     Job Title: - Sr. Data Science Consultant Durat...   Contract
# 9     • 3+ years related a professional experience  ...   Contract
# 11    Data Scientist EnvoyIT is looking for a Data S...  Full Time
# ...                                                 ...        ...
# 9612  Duration: 6 months to start will be extended L...   Contract
# 9756  RESPONSIBILITIES: Kforce has a client in searc...   Contract
# 9886  RESPONSIBILITIES: Kforce has a client that is ...  Full Time
# 9985  RESPONSIBILITIES: Kforce has a client that is ...  Full Time
# 9986  RESPONSIBILITIES: Kforce has a client in searc...   Contract
#
# [1721 rows x 8 columns]
